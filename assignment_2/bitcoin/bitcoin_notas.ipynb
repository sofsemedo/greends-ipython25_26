# %% [markdown]
# ```
# import sys
# ```
#
# * Importar o módulo sys, que permite aceder a argumentos passados na linha de comando e usar sys.exit() para terminar o programa com mensagens de erro.

# %% [markdown]
# ```
# def main():
# ```
#
# * definir a função principal main() do programa.

# %% [markdown]
#  ```
#  # 1. Verificar argumento
#     if len(sys.argv) != 2:
#         sys.exit("Missing command-line argument")
# ```
#
# * verificar se o utilizador passou exatamente um argumento além do nome do ficheiro (sys.argv[0] é sempre o nome do ficheiro).
#
# * Se não, termina o programa com a mensagem de erro "Missing command-line argument".

# %% [markdown]
# ```
#  try:
#         n = float(sys.argv[1])
#     except ValueError:
#         sys.exit("Command-line argument is not a number"
# ```
#
# * tenta converter o argumento passado (sys.argv[1]) para um número do tipo float.
#
# * Se o argumento não for um número (por exemplo "gato"), o programa termina com a mensagem de erro "Command-line argument is not a number".

# %% [markdown]
# ```
#     price = 34000.0  # valor de exemplo
#
# ```
# * 2. Valor fixo do preço do Bitcoin (em USD)
# * Nota: Não é possível aceder à API da CoinCap neste computador de trabalho,
# * portanto o preço do Bitcoin é simulado com um valor fixo.

# %% [markdown]
#    3. Calcular e imprimir custo
#
#     ```
#     cost = n * price
#     print(f"${cost:,.4f}") ```
#
#
# * multiplica o número de bitcoins (n) pelo preço (price) para calcular o custo total.
#
#
# ```
# f"${cost:,.4f}"
# ```
#
# * formata o número:
#
#  - $ → símbolo de dólares
#
#  - , → separador de milhares
#
#  -  .4f → 4 casas decimais

# %%
if __name__ == "__main__":
    main()

# %% [markdown]
# ```
# if __name__ == "__main__":
#     main()
# ```
#
# * garante que a função main() só é executada se o ficheiro for executado diretamente e não se for importado como módu

# %% [markdown]
# # Testes para bitcoin.py

# %% [markdown]
# * Argumento válido (número inteiro)
# ```
# PS C:\Users\ssemedo\OneDrive - The Summer Berry Company\Desktop\github\assignment_2\bitcoin> python bitcoin.py 1
# $34,000.0000  (preço obtido através de valor fixo (offline))
# ```
# * Argumento válido (número decimal)
#
# ```
# PS C:\Users\ssemedo\OneDrive - The Summer Berry Company\Desktop\github\assignment_2\bitcoin> python bitcoin.py 2.5
# $85,000.0000  (preço obtido através de valor fixo (offline))
# ```
# * Sem argumento
# ```
# PS C:\Users\ssemedo\OneDrive - The Summer Berry Company\Desktop\github\assignment_2\bitcoin> python bitcoin.py
# Missing command-line argument
# ```
# * Argumento inválido
# ```
# PS C:\Users\ssemedo\OneDrive - The Summer Berry Company\Desktop\github\assignment_2\bitcoin> python bitcoin.py gato
# Command-line argument is not a number
# ```
#
# * Check50
# ```
#
# Command-line argument is not a number
# assignment_2/bitcoin/ $ check50 cs50/problems/2022/python/bitcoin
# Connecting......
# Authenticating...
# Verifying......
# Preparing.....
# Uploading......
# Waiting for results..................
# Results for cs50/problems/2022/python/bitcoin generated by check50 v4.0.0.dev0
# :) bitcoin.py exists
# :) bitcoin.py exits given no command-line argument
# :) bitcoin.py exits given non-numeric command-line argument
# :) bitcoin.py provides price of 1 Bitcoin to 4 decimal places
# :) bitcoin.py provides price of 2 Bitcoin to 4 decimal places
# :) bitcoin.py provides price of 2.5 Bitcoin to 4 decimal places
# To see more detailed results go to https://submit.cs50.io/check50/0acbea4f831141c83e4315a335e6548d5de495e0
#
# ```
